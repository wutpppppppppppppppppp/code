# %% [markdown]
# # Lab 4: Data Visualization and EDA

# %% [markdown]
# Objectives:
# - To gain practice in creating various data visualizations
# - To encourage students to perform EDA on the required dataset

# %% [markdown]
# ***

# %% [markdown]
# 1. Load all Superstore datasets.
#
# *Note: The same dataset used in Lab 3*

# %%
# Write your code here
import pandas as pd
superstore_order = pd.read_csv('Superstore\superstore_order.csv')
superstore_people = pd.read_csv('Superstore\superstore_people.csv')
superstore_return = pd.read_csv('Superstore\superstore_return.csv')
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\s'
# <>:4: SyntaxWarning: invalid escape sequence '\s'
# <>:5: SyntaxWarning: invalid escape sequence '\s'
# <>:3: SyntaxWarning: invalid escape sequence '\s'
# <>:4: SyntaxWarning: invalid escape sequence '\s'
# <>:5: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\woosh\AppData\Local\Temp\ipykernel_20532\3353402875.py:3: SyntaxWarning: invalid escape sequence '\s'
#   superstore_order = pd.read_csv('Superstore\superstore_order.csv')
# C:\Users\woosh\AppData\Local\Temp\ipykernel_20532\3353402875.py:4: SyntaxWarning: invalid escape sequence '\s'
#   superstore_people = pd.read_csv('Superstore\superstore_people.csv')
# C:\Users\woosh\AppData\Local\Temp\ipykernel_20532\3353402875.py:5: SyntaxWarning: invalid escape sequence '\s'
#   superstore_return = pd.read_csv('Superstore\superstore_return.csv')
# C:\Users\woosh\AppData\Local\Temp\ipykernel_20532\3353402875.py:2: DeprecationWarning:
# ...

# %% [markdown]
# 2. Determine shape of each dataset (print out the results as well).

# %%
# Write your code here
print("order shape -> " + str(superstore_order.shape) + "\npeople shape -> " + str(superstore_people.shape) + "\nreturn shape -> " + str(superstore_return.shape))
# Out:
# order shape -> (8880, 21)
# people shape -> (4, 2)
# return shape -> (296, 2)

# %% [markdown]
# 3. Show information of the dataset.

# %%
# Write your code here (3.1)
# print(superstore_order.info())
# print(superstore_people.info())
# print(superstore_return.info())
print(superstore_people.isnull().any())
print(superstore_order.isnull().any())
print(superstore_return.isnull().any())
# Out:
# Person    False
# Region    False
# dtype: bool
# Row ID           False
# Order ID         False
# Order Date       False
# Ship Date        False
# Ship Mode        False
# Customer ID      False
# Customer Name    False
# Segment          False
# Country          False
# City             False
# State            False
# Postal Code      False
# Region           False
# Product ID       False
# Category         False
# Sub-Category     False
# Product Name     False
# Sales            False
# Quantity         False
# Discount         False
# Profit           False
# dtype: bool
# Returned    False
# Order ID    False
# dtype: bool

# %% [markdown]
# 4. Are there any missing values? If so, in which column?
#
# Ans: There is no missing value.

# %% [markdown]
# 5.
# - 5.1 List unique segments
# - 5.2 List unique segments and their corresponding count
# - 5.3 Create a pie chart to demonstrate unique segments and their count
# - 5.4 Briefly describe what could be interpreted from this pie chart
#
# *Note: please create additional cells to answer 5.2 - 5.3*

# %%
# Write your code here (5.1)
superstore_order.Segment.unique()
# Out:
# array(['Consumer', 'Corporate', 'Home Office'], dtype=object)

# %%
# Write your code here (5.2)
superstore_order[['Segment','Category']].value_counts()
# Out:
# Segment      Category
# Consumer     Office Supplies    2789
# Corporate    Office Supplies    1613
# Consumer     Furniture           976
# Home Office  Office Supplies     958
# Consumer     Technology          848
# Corporate    Furniture           575
#              Technology          485
# Home Office  Furniture           329
#              Technology          307
# Name: count, dtype: int64

# %%
# Write your code here (5.3) Create a pie chart to demonstrate unique segments and their count
import matplotlib.pyplot as plt
plt.pie(x=superstore_order['Segment'].value_counts(),labels=superstore_order['Segment'].unique(),autopct='%1.1f%%')
plt.title('Order Segments')
plt.legend(title = 'Segment')
plt.show()
import plotly.express as px
df_pie = pd.DataFrame({
    "segments" : superstore_order.Segment.unique(),
    "amount" : superstore_order.Segment.value_counts()
})
fig = px.pie(df_pie, values="amount", names ="segments", title = "Order Segments")
fig.show()

# %% [markdown]
# ***Using plotly, The graph doesn't show up in pdf***

# %% [markdown]
# Answer for the question 5.4
#
# Ans: You can see that consumer segment is a biggest segment, following by corporate segment. Lastly, the smallest is home office segment.

# %% [markdown]
# 6.
# - 6.1 List unique states
# - 6.2 List top-10 unique states and their corresponding count
# - 6.3 Create a bar chart (vertical) to demonstrate the count of top-10 unique states
# - 6.4 Based on 6.2, also include the total sales of these states (show your result as a dataframe)
# - 6.5 Using the result from 6.4, if you were the owner of this superstore, what information could be interpreted from this result?
#
# *Note: please create additional cells to answer 6.2 - 6.4*

# %%
# Write your code here (6.1)
superstore_order.State.unique()
# Out:
# array(['Kentucky', 'California', 'Florida', 'North Carolina',
#        'Washington', 'Texas', 'Wisconsin', 'Utah', 'Nebraska',
#        'Pennsylvania', 'Illinois', 'Minnesota', 'Michigan', 'Delaware',
#        'Indiana', 'New York', 'Arizona', 'Virginia', 'Tennessee',
#        'Alabama', 'South Carolina', 'Oregon', 'Colorado', 'Iowa', 'Ohio',
#        'Missouri', 'Oklahoma', 'New Mexico', 'Louisiana', 'Connecticut',
#        'New Jersey', 'Massachusetts', 'Georgia', 'Nevada', 'Rhode Island',
#        'Mississippi', 'Arkansas', 'Montana', 'New Hampshire', 'Maryland',
#        'District of Columbia', 'Kansas', 'Vermont', 'Maine',
#        'South Dakota', 'Idaho', 'North Dakota', 'Wyoming',
#        'West Virginia'], dtype=object)

# %%
# Write your code here (6.2)
superstore_order["State"].value_counts(ascending=False).head(10)
# Out:
# State
# California        1754
# New York          1001
# Texas              860
# Pennsylvania       531
# Washington         452
# Illinois           427
# Ohio               396
# Florida            339
# Michigan           230
# North Carolina     229
# Name: count, dtype: int64

# %%
# Write your code here (6.3) Create a bar chart (vertical) to demonstrate the count of top-10 unique states
plt.bar(x=superstore_order['State'].unique(),height=superstore_order['State'].value_counts(sort=False),label='count')
plt.title('Vertical bar chart for superstore order states')
plt.xlabel('States')
plt.ylabel('Frequency')
plt.legend()
plt.xticks(rotation=90,size=5)
plt.show()
# df_bar = superstore_order["State"].value_counts(ascending=False).head(10)
# fig = px.bar(df_bar, title = "Top 10 states with the most order")
# fig.show()

# %%
# Based on 6.2, also include the total sales of these states (show your result as a dataframe)
total_sales_by_state = superstore_order.groupby("State")["Sales"].sum()
top_10_states = superstore_order["State"].value_counts(ascending=False).head(10).index
total_sales_df = pd.DataFrame({
    "Amount" : superstore_order["State"].value_counts(ascending=False).head(10),
    'Total Sales': total_sales_by_state.loc[top_10_states].values
})
total_sales_df
# Out:
# State
# Alabama                  19272.4900
# Arizona                  32990.1060
# Arkansas                  9427.4400
# California              399195.4555
# Colorado                 31080.8060
# Connecticut              12829.0570
# Delaware                 26379.4290
# District of Columbia      2865.0200
# Florida                  84083.0880
# Georgia                  47940.1900
# Idaho                     4257.8360
# Illinois                 71456.1780
# Indiana                  48231.1400
# Iowa                      4315.0400
# Kansas                    2914.3100
# Kentucky                 32418.5200
# Louisiana                 7589.5400
# Maine                      653.4100
# Maryland                 23145.6830
# Massachusetts            25217.6840
# Michigan                 62147.6960
# Minnesota                29254.1000
# Mississippi              10394.2200
# Missouri                 14074.6400
# Montana                   5589.3520
# Nebraska                  7025.0200
# ...

# %% [markdown]
# Answer for the question 6.5
#
# Ans: You will see that State that has the most order is Califonia, as well as the total sales. the least amount of order seems to be North Carolina in Top 10 states. Washingtons, even they have less purchased order, the total sales is larger than Pennsylvania.

# %% [markdown]
# 7.
# - 7.1 List unique categories
# - 7.2 Create a bar chart (horizontal) to demonstrate the proportion of these categories
# - 7.3 Compute the ratio of these categories in percentage and print the results
#
# *Note: please create additional cells to answer 7.2 - 7.3*

# %%
# Write your code here (7.1)
superstore_order["Category"].unique()
# Out:
# array(['Furniture', 'Office Supplies', 'Technology'], dtype=object)

# %%
superstore_order["Category"].value_counts()
# Out:
# Category
# Office Supplies    5360
# Furniture          1880
# Technology         1640
# Name: count, dtype: int64

# %%
# Write your code here (7.2) Create a bar chart (horizontal) to demonstrate the proportion of these categories
plt.barh(y=superstore_order['Category'].unique(),width=superstore_order['Category'].value_counts(),label='count')
plt.xlabel('Frequency')
plt.ylabel('Categories')
plt.legend()
plt.yticks(size =5 )
plt.title('Horizontal bar chart')
plt.show()
# pyplot
df_bar = superstore_order["Category"].value_counts()
fig = px.bar(df_bar, title = "Catagories being purchased", orientation='h')
fig.show()

# %%
# Write your code here (7.3) Compute the ratio of these categories in percentage and print the results
superstore_order["Category"].value_counts()
print(superstore_order["Category"].value_counts()/superstore_order["Category"].value_counts().sum()*100)
# Out:
# Category
# Office Supplies    60.360360
# Furniture          21.171171
# Technology         18.468468
# Name: count, dtype: float64

# %% [markdown]
# 8. Update the type of all columns that contain dates to *datetime* and show information after an update.

# %%
# write your code here
superstore_order['Order Date'] = pd.to_datetime(superstore_order["Order Date"], format="%d/%m/%Y")
superstore_order['Ship Date'] = pd.to_datetime(superstore_order["Ship Date"], format="%d/%m/%Y")
print(superstore_order['Order Date'].dtype)
print(superstore_order['Ship Date'].dtype)
# Out:
# datetime64[ns]
# datetime64[ns]

# %% [markdown]
# 9. Create a new column "Processing time day" to show number of days taken to ship an order and show your result in a dataframe format.
#
# *Hint: The duration starts as soon as the item has been ordered and ends once the order has successfully shipped.*

# %%
# write your code here
superstore_order["Processing time day"] = superstore_order["Ship Date"] - superstore_order["Order Date"]
superstore_order
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 1          2  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 2          3  CA-2016-138688 2016-06-12 2016-06-16    Second Class
# 3          4  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 4          5  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# ...      ...             ...        ...        ...             ...
# 8875    8876  US-2016-141264 2016-08-13 2016-08-19  Standard Class
# 8876    8877  US-2016-141264 2016-08-13 2016-08-19  Standard Class
# 8877    8878  CA-2017-126928 2017-09-17 2017-09-23  Standard Class
# 8878    8879  CA-2017-126928 2017-09-17 2017-09-23  Standard Class
# 8879    8880  US-2015-107944 2015-03-23 2015-03-25     First Class
#
#      Customer ID    Customer Name    Segment        Country             City  \
# 0       CG-12520      Claire Gute   Consumer  United States        Henderson
# ...

# %% [markdown]
# 10. Based on the result in 9.
# - 10.1 How many orders are there that take more than 5 days to process?
# - 10.2 Show the top 5 rows (expected output should contain these columns: Order ID, Order Date, Ship Date, Processing time day, Quantity)
# - 10.3 Plot the histogram based on the column Quantity
#
# *Note: please create additional cells to answer 10.2 - 10.3*

# %%
# Write your code here (10.1)
superstore_order[superstore_order["Processing time day"]>"5 days"].shape[0]
# Out:
# 1656

# %%
# Write your code here (10.2) 
# I'M NOT SURE THAT I MEED TO SHOW THE TOP 5 ROWS OF THE ORDERS THAT TAKE MORE THAN 5 DAYS OR NOT
superstore_order[superstore_order["Processing time day"]>"5 days"][["Order ID","Order Date","Ship Date","Processing time day","Quantity"]].head(5)
# Out:
#           Order ID Order Date  Ship Date Processing time day  Quantity
# 3   US-2015-108966 2015-10-11 2015-10-18              7 days         5
# 4   US-2015-108966 2015-10-11 2015-10-18              7 days         2
# 16  CA-2014-105893 2014-11-11 2014-11-18              7 days         6
# 53  CA-2016-105816 2016-12-11 2016-12-17              6 days         7
# 54  CA-2016-105816 2016-12-11 2016-12-17              6 days         5

# %%
# Write your code here (10.3) Plot the histogram based on the column Quantity
plt.hist(x= superstore_order['Quantity'],label = 'weight')
plt.xlabel('Quantity')
plt.ylabel('Count')
plt.title('Histogram')
plt.legend()
plt.show()
fig = px.histogram(superstore_order, x="Quantity")
fig.show()

# %% [markdown]
# [BONUS 20 pts] Determine the percentage of customers who:
# - B1) returned the product once
# - B2) returned the product at least once
# - B3) never returned the product
# - Finally, Plot a comparison of B2 and B3
#
# *Note: please create additional cells to answer the above points*

# %%
# Write your code here B1
customer_returned_once = superstore_order.merge(superstore_return[superstore_return["Returned"]=="Yes"],how="inner",on="Order ID")["Customer ID"].drop_duplicates(keep=False).shape[0]
customer_all = superstore_order["Customer ID"].drop_duplicates().count()
print(customer_returned_once/customer_all*100)
# Out:
# 7.858048162230672

# %%
# Write your code here B2
customer_returned_at_least = superstore_order.merge(superstore_return[superstore_return["Returned"]=="Yes"],how="inner",on="Order ID")["Customer ID"].drop_duplicates().shape[0]
print(customer_returned_at_least/customer_all*100)
# Out:
# 28.13688212927757

# %%
# Write your code here B3
bad_customer = customer_all - customer_returned_at_least
print(bad_customer/customer_all*100)
# Out:
# 71.86311787072243

# %%
# Write your code here B4
import matplotlib.pyplot as plt
df_bar = pd.DataFrame({
    "B2" : customer_returned_at_least,
    "B3" : bad_customer
}, index=[0])
df_bar.plot(kind='bar')
plt.ylabel('Person')
plt.title('Comparing between B2 and B3')
plt.show()
